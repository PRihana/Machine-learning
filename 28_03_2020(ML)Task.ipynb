# %% [markdown]
# <a href="https://colab.research.google.com/github/PRihana/Machine-learning/blob/master/28_03_2020(ML)Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Draw a line using given axis values with suitable label in the x axis , y axis and a title.
# x axis values
X = [1,2,3]
# y axis values
Y = [2,4,1]

# %%
X = [1,2,3]
Y = [2,4,1]
plt.plot(X, Y,)
plt.xlabel('x - axis')
plt.ylabel('Y - axis')
plt.title('Draw a line')
plt.show()

# %%
#Plot two or more lines with different widths and colors

# %%
x1=[0,0]
y1=[0,3]
x2=[0,4]
y2=[3,3]
x3=[4,4]
y3=[3,0]
plt.plot(x1,y1,'b',x2,y2,'r',x3,y3,'g','LineWidth',4,2,1)

# %%
#Plot two or more lines with different linestyles.

# %%
x1 = [10,20,30]
y1 = [20,40,10]
x2 = [10,20,30]
y2 = [40,10,30]
plt.xlabel('x - axis')
plt.ylabel('Y - axis')
plt.plot(x1,y1, color='b', linewidth = 3,  label = 'line1-dotted',linestyle='dotted')
plt.plot(x2,y2, color='maroon', linewidth = 5,  label = 'line2-dashed', linestyle='dashed')
plt.legend()
plt.show()

# %%
#Plot two or more lines and set the line markers of your choice

# %%
x = [1,2,3]
y = [2,4,1]
plt.plot(x, y, color='navy', linestyle='dashdot', linewidth = 3,
         marker='s',markerfacecolor='r',)

# %%
#Plot the data with given x and y values.
#Display only a part of it using xlim and ylim

# %%
x = [1,2,3]
y = [2,4,1]
line, = plt.plot(x, y, '-',color='chocolate')
line.set_antialiased(True)
plt.xlim(1, 3)
plt.ylim(2,5)
# Out:
# (2.0, 5.0)

# %%
#Plot several lines with different format styles in one command using arrays.Use the plot function only once

# %%
 t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
plt.show()

# %%
#Display a bar chart of the popularity of programming Languages.
Sample data:
Programming languages: Java, Python, PHP, JavaScript, C#, C++
Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]
plt.bar(x_pos, popularity, color=(0.4, 0.6, 0.8, 1.0), edgecolor='blue')
plt.xlabel("languages")
plt.ylabel("Popularity")
plt.xticks(x_pos, x)
# Out:
# ([<matplotlib.axis.XTick at 0x7fd8fb7a3470>,
# ...
#  [Text(0, 0, 'Java'),
#   Text(0, 0, 'Python'),
#   Text(0, 0, 'PHP'),
#   Text(0, 0, 'JavaScript'),
#   Text(0, 0, 'C#'),
#   Text(0, 0, 'C++')])

# %%
#Display a bar chart of the popularity of programming Languages. Use different color for each bar

# %%
plt.bar(languages, popularity, color = 'kmcyrb',  edgecolor = 'g', linestyle = '-.' )
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   """Entry point for launching an IPython kernel.
# <BarContainer object of 6 artists>

# %%
#For the above data create a pie chart

# %%
colors = ['blue', 'gold', 'yellowgreen', 'darkred', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0, 0, 0)  
# Plot
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.show()

# %%
#For the above data create a pie chart mention your choice of colors with hexadecimal values

# %%
from matplotlib import cm
colors = ['#1100de','#a12b3c','#012e3d','#ffcc99', '#11dd11', '#dd1122']
plt.pie(popularity,explode = (0.06, 0,0,0, 0, 0), autopct = '%0.01f%%', shadow = True, colors = colors)
plt.tight_layout()
plt.legend(languages, bbox_to_anchor=(1, 1.05))

# %%
#Draw a scatter plot taking a random distribution in X and Y and plotted against each other
use random.randn function

# %%
x =np.random.randn(10,3)
y = np.random.randn(10,3)
plt.scatter(x,y, edgecolor = 'indigo', marker = '^')

# %%
#Draw a scatter plot with empty circles taking a random distribution in X and Y and plotted against each other
use random.randn function

# %%
x = np.random.randn(50)
y = np.random.randn(50)
plt.scatter(x, y, color = 'deeppink',facecolor='none')

# %%
#draw a scatter plot using random distributions to generate circles of different sizes.

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = (np.random.sample(100) * 20) ** 2
plt.scatter(x,y, edgecolors='brown',s=sizes,color='slateblue')

# %%
#draw a histogram owith your choice of data generated with numpy

# %%
nums = np.array([0.5, 0.7, 1.0, 1.2, 1.3, 2.1])
bins = np.array([0, 1, 2, 3])
print("nums: ",nums)
print("bins: ",bins)
print("Result:", np.histogram(nums, bins))
plt.hist(nums, bins=bins)
plt.show()
# Out:
# nums:  [0.5 0.7 1.  1.2 1.3 2.1]
# bins:  [0 1 2 3]
# Result: (array([2, 3, 1]), array([0, 1, 2, 3]))
