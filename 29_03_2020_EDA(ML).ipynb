# %% [markdown]
# <a href="https://colab.research.google.com/github/PRihana/Machine-learning/blob/master/29_03_2020_EDA(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the data
data = pd.read_csv("/content/market_fact.csv")
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id  ...   Profit  Shipping_Cost  Product_Base_Margin
# 0  Ord_5446  Prod_16  SHP_7609  ...   -30.51           3.60                 0.56
# 1  Ord_5406  Prod_13  SHP_7549  ...     4.56           0.93                 0.54
# 2  Ord_5446   Prod_4  SHP_7610  ...  1148.90           2.50                 0.59
# 3  Ord_5456   Prod_6  SHP_7625  ...   729.34          14.30                 0.37
# 4  Ord_5485  Prod_17  SHP_7664  ...  1219.87          26.30                 0.38
#
# [5 rows x 10 columns]

# %%
# No of rows in the data
data.shape[0]
# Out:
# 8399

# %%
# Statistical descriptions
data.describe()
# Out:
#               Sales     Discount  ...  Shipping_Cost  Product_Base_Margin
# count   8399.000000  8399.000000  ...    8399.000000          8336.000000
# mean    1775.878179     0.049671  ...      12.838557             0.512513
# std     3585.050525     0.031823  ...      17.264052             0.135589
# min        2.240000     0.000000  ...       0.490000             0.350000
# 25%      143.195000     0.020000  ...       3.300000             0.380000
# 50%      449.420000     0.050000  ...       6.070000             0.520000
# 75%     1709.320000     0.080000  ...      13.990000             0.590000
# max    89061.050000     0.250000  ...     164.730000             0.850000
#
# [8 rows x 6 columns]

# %%
# description for categorical
data.describe(include=object)
# Out:
#          Ord_id Prod_id   Ship_id    Cust_id
# count      8399    8399      8399       8399
# unique     5506      17      7701       1832
# top     Ord_542  Prod_6  SHP_1378  Cust_1140
# freq          6    1225         4         30

# %%
# missing values
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %% [markdown]
# **Imputation**
#
#   - Filling the missing values
#
#   - Numerical columns
#
#      -  with a number
#
#      -  with mean or median or mode
#
#      -   using ML model make the missing value as output
#
# - categorical colu
#    -  with a new category
#      -  ex:'Unknown','?'
#    -  with mode (most frequent category)
#
# Here 63 missing values are there in the numerical column Product_Base_Margin

# %%
data['Product_Base_Margin'] = \
                data['Product_Base_Margin'].fillna(data['Product_Base_Margin'].mean())
data['Product_Base_Margin'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Exploratory Data Analysis(EDA)**

# %%
plt.hist(data['Sales'])
# Out:
# (array([8.047e+03, 2.580e+02, 7.800e+01, 1.300e+01, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.2400000e+00, 8.9081210e+03, 1.7814002e+04, 2.6719883e+04,
#         3.5625764e+04, 4.4531645e+04, 5.3437526e+04, 6.2343407e+04,
#         7.1249288e+04, 8.0155169e+04, 8.9061050e+04]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# - In the first bin(2.24 to 8908) we have 8047 entries in the data
# - Total no of entries 8399

# %%
plt.hist(data['Sales'])
plt.yscale('log')

# %%
plt.hist(data['Profit'])
# Out:
# (array([7.000e+00, 9.000e+00, 7.300e+01, 8.066e+03, 1.880e+02, 4.600e+01,
#         9.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-14140.7  , -10004.561,  -5868.422,  -1732.283,   2403.856,
#           6539.995,  10676.134,  14812.273,  18948.412,  23084.551,
#          27220.69 ]),
#  <a list of 10 Patch objects>)

# %%
np.log([7.000e+00, 9.000e+00, 7.300e+01, 8.066e+03, 1.880e+02, 4.600e+01,
        9.000e+00, 0.000e+00, 0.000e+00, 1.000e+00])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# array([1.94591015, 2.19722458, 4.29045944, 8.99541298, 5.23644196,
#        3.8286414 , 2.19722458,       -inf,       -inf, 0.        ])

# %%
plt.hist(data['Profit'])
plt.yscale("log")

# %%
plt.hist(data['Order_Quantity'])
# Out:
# (array([868., 847., 789., 816., 854., 827., 848., 825., 876., 849.]),
#  array([ 1. ,  5.9, 10.8, 15.7, 20.6, 25.5, 30.4, 35.3, 40.2, 45.1, 50. ]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(data['Prod_id'].value_counts().index,data['Prod_id'].value_counts())
# Out:
# <BarContainer object of 17 artists>

# %%
plt.barh(data['Prod_id'].value_counts().index,data['Prod_id'].value_counts())
# Out:
# <BarContainer object of 17 artists>

# %%
plt.boxplot(data['Order_Quantity'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6326cdb048>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6326ccec18>,
#   <matplotlib.lines.Line2D at 0x7f6326cdc710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6326cd47b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6326cdc320>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6326cce6a0>,
#   <matplotlib.lines.Line2D at 0x7f6326ccee80>]}

# %%
data['Order_Quantity'].describe()
# Out:
# count    8399.000000
# mean       25.571735
# std        14.481071
# min         1.000000
# 25%        13.000000
# 50%        26.000000
# 75%        38.000000
# max        50.000000
# Name: Order_Quantity, dtype: float64

# %%
plt.boxplot(data['Sales'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6326e82f98>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6326e9f2b0>,
#   <matplotlib.lines.Line2D at 0x7f6326e9f630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6326e9fbe0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6326e9fdd8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6326e82828>,
#   <matplotlib.lines.Line2D at 0x7f6326e823c8>]}

# %%
plt.boxplot(data['Sales'])
plt.yscale("log")

# %%
plt.boxplot(data['Profit'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6326eef828>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6326ee2278>,
#   <matplotlib.lines.Line2D at 0x7f6326ee25f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6326ee2cf8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6326ee2978>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6326eefb38>,
#   <matplotlib.lines.Line2D at 0x7f6326eefeb8>]}

# %%
plt.boxplot(data['Profit'])
plt.yscale("log")

# %%
data[data['Profit']<0]
# Out:
#         Ord_id  Prod_id   Ship_id  ...  Profit  Shipping_Cost  Product_Base_Margin
# 0     Ord_5446  Prod_16  SHP_7609  ...  -30.51           3.60             0.560000
# 5     Ord_5446   Prod_6  SHP_7608  ...  -47.64           6.15             0.370000
# 9     Ord_4725   Prod_6  SHP_6593  ...  -27.72           6.60             0.370000
# 13    Ord_2207  Prod_11  SHP_3093  ... -693.23          61.76             0.780000
# 14    Ord_2207  Prod_10  SHP_3006  ... -317.48          36.09             0.770000
# ...        ...      ...       ...  ...     ...            ...                  ...
# 8388  Ord_4424   Prod_1  SHP_6165  ... -335.06          35.00             0.512513
# 8390  Ord_5435  Prod_16  SHP_7594  ... -276.54           8.37             0.580000
# 8392  Ord_5384   Prod_9  SHP_7519  ...   -6.24           2.50             0.370000
# 8395  Ord_5411   Prod_6  SHP_7555  ...  -74.03           6.92             0.370000
# 8396  Ord_5388   Prod_6  SHP_7524  ...  -70.85           5.35             0.400000
#
# [4264 rows x 10 columns]

# %%
plt.scatter(data['Sales'],data['Profit'])

# %%
data1 = data[(data['Sales'] <50000) & (data['Profit']<20000)]
plt.scatter(data1['Sales'],data1['Profit'])

# %%
plt.scatter(data['Sales'],data['Profit'])
plt.xlim(0,50000)
plt.ylim(-20000,20000)

# %%
sns.distplot(data['Sales'])

# %%
sns.distplot(data['Sales'])
plt.yscale('log')

# %%
sns.distplot(data['Sales'],hist=False)

# %%
sns.distplot(data['Sales'],hist=False,rug=True)

# %%
sns.distplot(data['Order_Quantity'],hist=False,rug=True)

# %%
sns.countplot(data['Prod_id'])

# %%
sns.countplot(y=data['Prod_id'])

# %%
sns.countplot("Prod_id",data=data)

# %%
sns.jointplot("Profit","Sales",data=data)

# %%
data.columns[data.dtypes !=object]
# Out:
# Index(['Sales', 'Discount', 'Order_Quantity', 'Profit', 'Shipping_Cost',
#        'Product_Base_Margin'],
#       dtype='object')

# %%
Salse,Discount
Salse, Orderer_Quantityu

# %%
i = 0
plt.figure(figsize=(10,15))
for col in data.columns[data.dtypes !=object]:
    for col2 in data.columns[data.dtypes !=object]:
        i += 1
        plt.subplot(6,6,i)
        plt.scatter(data[col],data[col2])

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6322ec4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6322e56240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f63214ed208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f632149d470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f632144e6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63213fd940>]],
#       dtype=object)

# %%
data['Sales'].hist()

# %%
data.corr()
# Out:
#                         Sales  Discount  ...  Shipping_Cost  Product_Base_Margin
# Sales                1.000000 -0.019686  ...       0.434578             0.155794
# Discount            -0.019686  1.000000  ...      -0.001956             0.004062
# Order_Quantity       0.220582 -0.009649  ...      -0.011457             0.007817
# Profit               0.581960 -0.037128  ...      -0.021362            -0.112124
# Shipping_Cost        0.434578 -0.001956  ...       1.000000             0.371056
# Product_Base_Margin  0.155794  0.004062  ...       0.371056             1.000000
#
# [6 rows x 6 columns]

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)

# %%
prod_df = pd.read_csv("/content/prod_dimen.csv")
prod_df
# Out:
#    Product_Category            Product_Sub_Category  Prod_id
# 0   OFFICE SUPPLIES          STORAGE & ORGANIZATION   Prod_1
# 1   OFFICE SUPPLIES                      APPLIANCES   Prod_2
# 2   OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES   Prod_3
# 3        TECHNOLOGY    TELEPHONES AND COMMUNICATION   Prod_4
# 4         FURNITURE              OFFICE FURNISHINGS   Prod_5
# 5   OFFICE SUPPLIES                           PAPER   Prod_6
# 6   OFFICE SUPPLIES                    RUBBER BANDS   Prod_7
# 7        TECHNOLOGY            COMPUTER PERIPHERALS   Prod_8
# 8   OFFICE SUPPLIES                       ENVELOPES   Prod_9
# 9         FURNITURE                       BOOKCASES  Prod_10
# 10        FURNITURE                          TABLES  Prod_11
# 11  OFFICE SUPPLIES                          LABELS  Prod_12
# 12  OFFICE SUPPLIES             PENS & ART SUPPLIES  Prod_13
# 13       TECHNOLOGY                 COPIERS AND FAX  Prod_14
# 14        FURNITURE              CHAIRS & CHAIRMATS  Prod_15
# 15  OFFICE SUPPLIES   SCISSORS, RULERS AND TRIMMERS  Prod_16
# 16       TECHNOLOGY                 OFFICE MACHINES  Prod_17

# %%
final_df = pd.merge(data,prod_df)
final_df
# Out:
#         Ord_id  Prod_id  ... Product_Category           Product_Sub_Category
# 0     Ord_5446  Prod_16  ...  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 1     Ord_2978  Prod_16  ...  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 2     Ord_5484  Prod_16  ...  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 3     Ord_3730  Prod_16  ...  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 4     Ord_4143  Prod_16  ...  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# ...        ...      ...  ...              ...                            ...
# 8394  Ord_5467  Prod_14  ...       TECHNOLOGY                COPIERS AND FAX
# 8395   Ord_825  Prod_14  ...       TECHNOLOGY                COPIERS AND FAX
# 8396  Ord_5368  Prod_14  ...       TECHNOLOGY                COPIERS AND FAX
# 8397  Ord_1765  Prod_14  ...       TECHNOLOGY                COPIERS AND FAX
# 8398  Ord_3610  Prod_14  ...       TECHNOLOGY                COPIERS AND FAX
#
# [8399 rows x 12 columns]

# %%
sns.boxplot(x='Product_Category',y="Sales",data=final_df)

# %%
cust_df = pd.read_csv("/content/cust_dimen.csv")
cust_df
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 2          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# 3         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 4           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# ...                  ...      ...      ...              ...        ...
# 1827      NICOLE BRENNAN  ALBERTA     WEST         CONSUMER  Cust_1828
# 1828       JASON FORTUNE  ALBERTA     WEST        CORPORATE  Cust_1829
# 1829        HARRY GREENE  ALBERTA     WEST        CORPORATE  Cust_1830
# 1830     GRANT DONATELLI  ALBERTA     WEST         CONSUMER  Cust_1831
# 1831          MICK BROWN  ALBERTA     WEST         CONSUMER  Cust_1832
#
# [1832 rows x 5 columns]

# %%
final_df = pd.merge(final_df,cust_df)
final_df
# Out:
#         Ord_id  Prod_id   Ship_id  ...          Province    Region  Customer_Segment
# 0     Ord_5446  Prod_16  SHP_7609  ...           ALBERTA      WEST         CORPORATE
# 1     Ord_5406  Prod_13  SHP_7549  ...           ALBERTA      WEST         CORPORATE
# 2     Ord_5446   Prod_4  SHP_7610  ...           ALBERTA      WEST         CORPORATE
# 3     Ord_5456   Prod_6  SHP_7625  ...           ALBERTA      WEST         CORPORATE
# 4     Ord_5446   Prod_6  SHP_7608  ...           ALBERTA      WEST         CORPORATE
# ...        ...      ...       ...  ...               ...       ...               ...
# 8394   Ord_973   Prod_8  SHP_1343  ...  BRITISH COLUMBIA      WEST         CORPORATE
# 8395  Ord_1832   Prod_8  SHP_2526  ...      NEWFOUNDLAND  ATLANTIC    SMALL BUSINESS
# 8396  Ord_2010   Prod_8  SHP_2748  ...       NOVA SCOTIA  ATLANTIC         CORPORATE
# 8397  Ord_2988  Prod_14  SHP_4132  ...           ONTARIO   ONTARIO       HOME OFFICE
# 8398  Ord_1096  Prod_14  SHP_1512  ...           ONTARIO   ONTARIO       HOME OFFICE
#
# [8399 rows x 16 columns]

# %%
sns.boxplot(x='Product_Category',y="Sales",hue="Customer_Segment",data=final_df)

# %%
sns.boxplot(x='Customer_Segment',y="Sales",hue="Product_Category",data=final_df)

# %% [markdown]
# What is Impuattion?
#
# What is Exploratory Data Analysis?
#
# Possitively skewed,Negatively skewed
#
# Uniform distribution
#
# Distributions
#
# - Normal distribution
#
# - Gaussian Distribution
#
# - Probability Density function
#
# - Kernel density function
# Seaborn
#
# - distplot
#   - rug
#   - hist
# - barplot
# - boxplot
# - countplot
# - pairplot
# - jointplot
# - heatmap
# - How to visualise a combo of categorical and - numerical columns by using seaborn
